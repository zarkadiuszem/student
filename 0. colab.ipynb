# %% [markdown]
# # Rozdział 1

# %% [markdown]
# Skrypt uruchamiany jest na serwerze google - nie musimy mieć zainstalowanego języka Python na naszym komputerze.
# Zaleta - szereg bibliotek jest już zainstalowanych - więc wystarczy je tylko włączyć.

# %% [markdown]
# **Jak zacząć?**
#
# 1.   Logujemy się na nasze konto google
# 2.   Wpisujemy w wyszukiwarkę google colab
# 3. Klikamy pierwszy link (https://colab.research.google.com/)
# 4. W oknie dialogowym (na dole) wybieramy nowy notatnik
# 5. Nadajemy nazwę np. **Colab_wprowadzenie**
# 6. Z menu wybieram Plik -> Zapisz
# 7. Otwieram mój Dysk Google
# 8. Wyszukuję plik **Colab_wprowadzenie**
# 9. Następnym razem mogę utworzyć plik już bezpośrednio na dysku google

# %% [markdown]
# <h1> Duży napis </h1>
# (to nie jest rozdział - sekcja)

# %% [markdown]
# ## Podrozdział 1.1

# %% [markdown]
# ## Podrozdział 1.2

# %% [markdown]
# **Łamanie tekstu** <br>
# Nowa linia <br>
# *kursywa*

# %% [markdown]
# Lista:
# 1. pierwszy
# 2. drugi

# %% [markdown]
# Wypunktowanie:
#
# *   Element listy 1
# *   Element listy 2
#
#
# Drugi

# %% [markdown]
# Uruchomienie kodu <br>
# **shift + enter** - jednocześnie przechodzimy do kolejnej komórki <br>
# przycisk **ctrl + enter** lub **play** - wykonuje dany skrypt

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# # Nowa sekcja

# %%
#komentarze - lub wyłączenie części tekstu - jedna linia
'''komentarz wieloliniowy
tu mogą też być 3 podwójne " '''
1+1  # to dodawanie się wykona
# Out:
# 2

# %% [markdown]
# ### Dark Theme
# **Włączamy ciemne wyświetlanie ekranu (dark theme)**
# 1. Narzędzia
# 2. Ustawienia
# 3. Motyw "dark"

# %% [markdown]
# ### Zatrzymanie kodu
# **Jak zatrzymać kod (np. nieskończoną pętlę)?**
# 1. albo przycisk stop
# 2. albo - z menu - środowisko wykonawcze - przerwij wykonywanie kodu

# %% [markdown]
# ### Markup language
# - język znaczników (np. HTML)
# <h3> Nagłówek 3 w HTML-u </h3>

# %% [markdown]
# ### Kolejność wykonywania kodu
# Liczby z lewej strony [ ] określają kolejność wykonywania kodu przez programistę.
# Jeśli więc gdzieś wykonamy kod - np przypiszemy jakąś liczbę do zmiennej, to będzie ona dostępna nawet z wyższych pozycji notesu - o ile wykonamy polecenia później - liczy się moment wykonania a nie pozycja. Jeśli chcemy wykonać cały kod wybierz: Środowisko wykonawcze - Uruchom wszystko

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/Dane/DB.xlsx")
df.head(5)
# Out:
#    id   age sex  salary    education_level         ecology  \
# 0   1  18.0   M  4500.0  vocational school  strongly agree
# 1   2  19.0   F  4510.0        high school             NaN
# 2   3  20.0   M  4520.0  vocational school  strongly agree
# 3   4  21.0   F  4530.0        high school  strongly agree
# 4   5  22.0   M  4540.0  vocational school  strongly agree
#
#   artificial_intelligence life expectancy
# 0          strongly agree        disagree
# 1                disagree  strongly agree
# 2          strongly agree        disagree
# 3                disagree  strongly agree
# 4          strongly agree        disagree
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['id'].plot(kind='hist', bins=20, title='id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_4.groupby('education_level').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
